# %% [markdown]
# <a href="https://colab.research.google.com/github/vickdurazzo/pre_processamento_de_dados/blob/main/Normalization_vs_Standartization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importa o pandas
import pandas as pd

# %% [markdown]
# **lendo a base de dados**

# %%
# ler o dataset
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data", sep=",")

# %%
# define o nome das colunas
df.columns = [ 'Class'
              ,'alcohol'
             	,'malicAcid'
             	,'ash'
            	,'ashalcalinity'
             	,'magnesium'
            	,'totalPhenols'
             	,'flavanoids'
             	,'nonFlavanoidPhenols'
             	,'proanthocyanins'
            	,'colorIntensity'
             	,'hue'
             	,'od280_od315'
             	,'proline'
             ]

# %%
# imprime as 5 primeiras linhas
df.head()
# Out:
#    Class  alcohol  malicAcid   ash  ashalcalinity  magnesium  totalPhenols  \
# 0      1    13.20       1.78  2.14           11.2        100          2.65
# 1      1    13.16       2.36  2.67           18.6        101          2.80
# 2      1    14.37       1.95  2.50           16.8        113          3.85
# 3      1    13.24       2.59  2.87           21.0        118          2.80
# 4      1    14.20       1.76  2.45           15.2        112          3.27
#
#    flavanoids  nonFlavanoidPhenols  proanthocyanins  colorIntensity   hue  \
# 0        2.76                 0.26             1.28            4.38  1.05
# 1        3.24                 0.30             2.81            5.68  1.03
# 2        3.49                 0.24             2.18            7.80  0.86
# 3        2.69                 0.39             1.82            4.32  1.04
# 4        3.39                 0.34             1.97            6.75  1.05
#
#    od280_od315  proline
# 0         3.40     1050
# ...

# %%
# estatística descritiva
df.describe()
# Out:
#             Class     alcohol   malicAcid         ash  ashalcalinity  \
# count  177.000000  177.000000  177.000000  177.000000     177.000000
# mean     1.943503   12.993672    2.339887    2.366158      19.516949
# std      0.773991    0.808808    1.119314    0.275080       3.336071
# min      1.000000   11.030000    0.740000    1.360000      10.600000
# 25%      1.000000   12.360000    1.600000    2.210000      17.200000
# 50%      2.000000   13.050000    1.870000    2.360000      19.500000
# 75%      3.000000   13.670000    3.100000    2.560000      21.500000
# max      3.000000   14.830000    5.800000    3.230000      30.000000
#
#         magnesium  totalPhenols  flavanoids  nonFlavanoidPhenols  \
# count  177.000000    177.000000  177.000000           177.000000
# mean    99.587571      2.292260    2.023446             0.362316
# std     14.174018      0.626465    0.998658             0.124653
# min     70.000000      0.980000    0.340000             0.130000
# ...

# %%
# selecionando algumas colunas
df_sub = df[['proline','alcohol','malicAcid','magnesium','flavanoids']]

# %% [markdown]
# > **Pelo boxplot temos uma prova mais visual como cada coluna esta em escalas extremamente distintas**

# %%
# plota boxplot de algumas colunas
import seaborn as sns
ax = sns.boxplot(data=df_sub)

# %%
# estatística descritiva
df_sub.describe()
# Out:
#            proline     alcohol   malicAcid   magnesium  flavanoids
# count   177.000000  177.000000  177.000000  177.000000  177.000000
# mean    745.096045   12.993672    2.339887   99.587571    2.023446
# std     314.884046    0.808808    1.119314   14.174018    0.998658
# min     278.000000   11.030000    0.740000   70.000000    0.340000
# 25%     500.000000   12.360000    1.600000   88.000000    1.200000
# 50%     672.000000   13.050000    1.870000   98.000000    2.130000
# 75%     985.000000   13.670000    3.100000  107.000000    2.860000
# max    1680.000000   14.830000    5.800000  162.000000    5.080000

# %% [markdown]
# **verificando a distribuição de cada coluna**

# %%
# distribuição da coluna alcohol
ax = sns.distplot(df_sub.alcohol)
# Out:
# <ipython-input-10-60a1291a0892>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(df_sub.alcohol)

# %%
# distribuição da coluna malicAcid
ax = sns.distplot(df_sub.malicAcid, color='y')
# Out:
# <ipython-input-11-157de997f3ff>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(df_sub.malicAcid, color='y')

# %%
# distribuição da coluna magnesium
ax = sns.distplot(df_sub.magnesium, color='g')
# Out:
# <ipython-input-12-0ab815d988b4>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(df_sub.magnesium, color='g')

# %%
# distribuição da coluna magnesium
ax = sns.distplot(df_sub.flavanoids, color='r')
# Out:
# <ipython-input-13-4f92f2d00799>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(df_sub.flavanoids, color='r')

# %% [markdown]
# **Aplicando o Standartization**

# %%
# importa o Standscaler da scikit-learn
from sklearn.preprocessing import StandardScaler

# %%
# criando novo dataframe com as colunas escolhidas
scaled_features = df[['proline','alcohol','malicAcid','magnesium','flavanoids']]
print(scaled_features.head(5))
# Out:
#    proline  alcohol  malicAcid  magnesium  flavanoids
# 0     1050    13.20       1.78        100        2.76
# 1     1185    13.16       2.36        101        3.24
# 2     1480    14.37       1.95        113        3.49
# 3      735    13.24       2.59        118        2.69
# 4     1450    14.20       1.76        112        3.39

# %%
# cria o objeto obj_std
obj_std = StandardScaler().fit(scaled_features.values)

# %%
# aplica o padronizador nos dados
df_std = obj_std.transform(scaled_features.values)

# %%
#imprimi os dados
df_std

# %%
#Adiciona os novos valores no array
scaled_features[['proline','alcohol','malicAcid','magnesium','flavanoids']] = df_std
print(scaled_features)
# Out:
#       proline   alcohol  malicAcid  magnesium  flavanoids
# 0    0.971052  0.255824  -0.501624   0.029180    0.739636
# 1    1.400998  0.206229   0.018020   0.099932    1.221645
# 2    2.340509  1.706501  -0.349315   0.948953    1.472691
# 3   -0.032154  0.305420   0.224086   1.302712    0.669343
# 4    2.244965  1.495719  -0.519543   0.878201    1.372273
# ..        ...       ...        ...        ...         ...
# 172 -0.016230  0.888171   2.965658  -0.324579   -1.419361
# 173  0.015618  0.503803   1.406725   0.170684   -1.278776
# 174  0.286324  0.342617   1.738222   1.444215   -1.339027
# 175  0.302248  0.218628   0.224086   1.444215   -1.349068
# 176 -0.589490  1.408926   1.576953  -0.253827   -1.268734
#
# [177 rows x 5 columns]
# <ipython-input-62-784007ef8701>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# visualizando o boxplot dos dados
import seaborn as sns
from matplotlib import pyplot as plt
plt.figure(figsize=(10,6))

ax = sns.boxplot(data=scaled_features)

# %%
# transforma em dataframe
df_std = pd.DataFrame(scaled_features)

# %%
# imprime as estatísticas descritivas do conjunto
df_std.describe()
# Out:
#             proline       alcohol     malicAcid     magnesium    flavanoids
# count  1.770000e+02  1.770000e+02  1.770000e+02  1.770000e+02  1.770000e+02
# mean   1.605746e-16 -5.218675e-16  2.810056e-16 -8.028731e-17  1.605746e-16
# std    1.002837e+00  1.002837e+00  1.002837e+00  1.002837e+00  1.002837e+00
# min   -1.487599e+00 -2.434746e+00 -1.433400e+00 -2.093373e+00 -1.690491e+00
# 25%   -7.805774e-01 -7.856866e-01 -6.628933e-01 -8.198411e-01 -8.268924e-01
# 50%   -2.327949e-01  6.984037e-02 -4.209899e-01 -1.123234e-01  1.069996e-01
# 75%    7.640417e-01  8.385748e-01  6.810145e-01  5.244425e-01  8.400546e-01
# max    2.977465e+00  2.276852e+00  3.100048e+00  4.415790e+00  3.069345e+00

# %% [markdown]
# **Aplicando Normalização usando Scikit-learn**

# %%
# importa o MinMaxScaler
from sklearn.preprocessing import MinMaxScaler

# %%
# imprime as 5 primeiras linhas
df.head()
# Out:
#    Class  alcohol  malicAcid   ash  ashalcalinity  magnesium  totalPhenols  \
# 0      1    13.20       1.78  2.14           11.2        100          2.65
# 1      1    13.16       2.36  2.67           18.6        101          2.80
# 2      1    14.37       1.95  2.50           16.8        113          3.85
# 3      1    13.24       2.59  2.87           21.0        118          2.80
# 4      1    14.20       1.76  2.45           15.2        112          3.27
#
#    flavanoids  nonFlavanoidPhenols  proanthocyanins  colorIntensity   hue  \
# 0        2.76                 0.26             1.28            4.38  1.05
# 1        3.24                 0.30             2.81            5.68  1.03
# 2        3.49                 0.24             2.18            7.80  0.86
# 3        2.69                 0.39             1.82            4.32  1.04
# 4        3.39                 0.34             1.97            6.75  1.05
#
#    od280_od315  proline
# 0         3.40     1050
# ...

# %%
# treina o algoritmo e cria o objeto obj_norm
obj_norm = MinMaxScaler().fit(df)

# %%
# aplica o normalizador
norm_df = obj_norm.transform(df)

# %%
# imprime os dados normalizados
norm_df
# Out:
# array([[0.        , 0.57105263, 0.2055336 , ..., 0.46341463, 0.78021978,
#         0.55064194],
#        [0.        , 0.56052632, 0.3201581 , ..., 0.44715447, 0.6959707 ,
#         0.64693295],
#        [0.        , 0.87894737, 0.23913043, ..., 0.30894309, 0.7985348 ,
#         0.85734665],
#        ...,
#        [1.        , 0.58947368, 0.69960474, ..., 0.08943089, 0.10622711,
#         0.39728959],
#        [1.        , 0.56315789, 0.36561265, ..., 0.09756098, 0.12820513,
#         0.40085592],
#        [1.        , 0.81578947, 0.66403162, ..., 0.10569106, 0.12087912,
#         0.20114123]])

# %% [markdown]
# > **Podemos verificar que com a normalização os dados estão entre 0 a 1, mas as medianas estão em uma altura diferentes, eles foram reescalado para se encaixar na forma de 0 a 1, mas não estão padronizados**

# %%
# visualiza os boxplots
import seaborn as sns
from matplotlib import pyplot as plt
plt.figure(figsize=(10,6))
ax = sns.boxplot(data=norm_df)

# %%
# transforma o numpy array para um dataframe
norm_df = pd.DataFrame(norm_df)

# %%
# estatística descritiva
norm_df.describe()
# Out:
#                0           1           2           3           4           5   \
# count  177.000000  177.000000  177.000000  177.000000  177.000000  177.000000
# mean     0.471751    0.516756    0.316183    0.538053    0.459637    0.321604
# std      0.386996    0.212844    0.221208    0.147102    0.171962    0.154065
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.350000    0.169960    0.454545    0.340206    0.195652
# 50%      0.500000    0.531579    0.223320    0.534759    0.458763    0.304348
# 75%      1.000000    0.694737    0.466403    0.641711    0.561856    0.402174
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#                6           7           8           9           10          11  \
# count  177.000000  177.000000  177.000000  177.000000  177.000000  177.000000
# mean     0.452503    0.355157    0.438333    0.371277    0.322082    0.387791
# ...

# %% [markdown]
# ## **Quando usar Padronização ou Normalização?**
#
# *   Algoritmos que utilizam cálculos de distância. (Knn, K-means, SVM).
# *   Algoritmos que usam Gradient Decendent.
# *   Algoritmos baseados em árvores.
# *   Redes Neurais.
